# %% [markdown]
# # General Task
#
# An e-commerce shop would like to onboard new suppliers efficiently. To enable the onboarding process, the customer needs
# us to integrate product data from suppliers in various formats and styles into the pre-defined data structure of their e-commerce
# shop application.

# %% [markdown]
# # 3. Integration
#
# Data Integration is to transform the supplier data with a specific data schema into a new dataset with target data schema,
# such as to:
# - keep any attributes that you can map to the target schema
# - discard attributes not mapped to the target schema
# - keep the number of records as unchanged
#
# Input: normalised supplier data
#
#
# Output: integrated supplier data

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
import xlsxwriter

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ### 3.1 Load dataset from part 2

# %%
target_file = '../data/Target Data.xlsx'
data_tar = pd.read_excel(target_file)
data_tar.head()
# Out:
#                   carType  color           condition currency drive  \
# 0  Convertible / Roadster  White                Used      USD   LHD
# 1  Convertible / Roadster  Other  Original Condition      USD   LHD
# 2  Convertible / Roadster  White                Used      USD   LHD
# 3  Convertible / Roadster   Blue                Used      USD   LHD
# 4  Convertible / Roadster  Black  Original Condition      USD   LHD
#
#             city country         make  manufacture_year  mileage mileage_unit  \
# 0         Zuzwil      CH       Toyota              1983      0.0    kilometer
# 1         London      GB      Ferrari              2001      0.0         mile
# 2  Scotts Valley      US      Porsche              1989      0.0         mile
# 3         London      GB  Rolls-Royce              1961      0.0    kilometer
# 4      Hong Kong      HK      Gumpert              2010      0.0    kilometer
#
#              model   model_variant  price_on_request type  zip  \
# 0           Celica    2800 i Supra             False  car  NaN
# 1              550             NaN              True  car  NaN
# 2          911 "G"             NaN              True  car  NaN
# 3  Silver Cloud II             NaN             False  car  NaN
# 4           Apollo  Apollo S 800hp             False  car  NaN
#
#    manufacture_month fuel_consumption_unit
# 0                3.0      l_km_consumption
# 1                NaN                   NaN
# 2                NaN                   NaN
# 3                NaN                   NaN
# 4                NaN                   NaN

# %%
file = './output/normalisation/normalisation.csv'
data = pd.read_csv(file, index_col=0)
data.head()
# Out:
#           BodyTypeText BodyColorText ConditionTypeText    City       MakeText  \
# ID
# 1            Limousine     anthrazit          Occasion  Zuzwil  MERCEDES-BENZ
# 2                Kombi     anthrazit          Occasion  Zuzwil           AUDI
# 3                Kombi     anthrazit          Occasion  Zuzwil           AUDI
# 4                Coupé     anthrazit          Occasion  Zuzwil      CHEVROLET
# 5   SUV / Geländewagen     anthrazit          Occasion  Zuzwil        PORSCHE
#
#    ModelText                     ModelTypeText     DriveTypeText  \
# ID
# 1      E 320            E 320 Elégance 4-Matic            Allrad
# 2        RS6         RS6 Avant 5.0 V10 quattro            Allrad
# 3        RS6                 RS6 Avant quattro            Allrad
# 4   CORVETTE                      Corvette Z06  Hinterradantrieb
# 5    CAYENNE  Cayenne Turbo Techart Magnum Kit            Allrad
#
#       TransmissionTypeText  FirstRegMonth  FirstRegYear     Km   Ccm  \
# ID
# 1                  Automat              1          1999  31900  3199
# 2      Automat sequentiell              7          2008  25400  4991
# 3      Automat sequentiell             10          2002  38500  4172
# 4   Schaltgetriebe manuell              6          2015    200  6162
# 5      Automat sequentiell              1          2010   2900  4806
#
#    Co2EmissionText ConsumptionRatingText ConsumptionTotalText  Doors  \
# ID
# 1         275 g/km                   NaN         11.5 l/100km      4
# 2         333 g/km                     G         14.0 l/100km      5
# 3         350 g/km                     G         14.6 l/100km      5
# 4         291 g/km                     G         12.7 l/100km      2
# 5         270 g/km                     G         11.5 l/100km      5
#
#    FuelTypeText   Hp InteriorColorText                          Properties  \
# ID
# 1        Benzin  224              grau                            "Ab MFK"
# 2        Benzin  580               NaN                            "Ab MFK"
# 3        Benzin  450             beige                            "Ab MFK"
# 4        Benzin  660           schwarz  "Ab MFK", "Direkt-/Parallelimport"
# 5        Benzin  500           schwarz                            "Ab MFK"
#
#     Seats                          TypeName BodyColorText_new  \
# ID
# 1       5            E 320 Elégance 4-Matic         anthrazit
# 2       5         RS6 Avant 5.0 V10 quattro         anthrazit
# 3       5                 RS6 Avant quattro         anthrazit
# 4       2                      Corvette Z06         anthrazit
# 5       5  Cayenne Turbo Techart Magnum Kit         anthrazit
#
#    BodyColorText_trans  color           make Country
# ID
# 1           Anthracite  Other  Mercedes-Benz      CH
# 2           Anthracite  Other           Audi      CH
# 3           Anthracite  Other           Audi      CH
# 4           Anthracite  Other      Chevrolet      CH
# 5           Anthracite  Other        Porsche      CH

# %% [markdown]
# ### 3.2. Identify attributes that can be mapped to the target schema
#
# Here we have to assume that the attributes we identified in the normalisation step were normalised, even though they are not, because we did not carry out the normalisation but only explained how we would do it.

# %%
data.columns.tolist()
# Out:
# ['BodyTypeText',
#  'BodyColorText',
#  'ConditionTypeText',
#  'City',
#  'MakeText',
#  'ModelText',
#  'ModelTypeText',
#  'DriveTypeText',
#  'TransmissionTypeText',
#  'FirstRegMonth',
#  'FirstRegYear',
#  'Km',
#  'Ccm',
#  'Co2EmissionText',
#  'ConsumptionRatingText',
#  'ConsumptionTotalText',
#  'Doors',
#  'FuelTypeText',
#  'Hp',
#  'InteriorColorText',
#  'Properties',
#  'Seats',
#  'TypeName',
#  'BodyColorText_new',
#  'BodyColorText_trans',
#  'color',
#  'make',
#  'Country']

# %%
data_tar.columns.tolist()
# Out:
# ['carType',
#  'color',
#  'condition',
#  'currency',
#  'drive',
#  'city',
#  'country',
#  'make',
#  'manufacture_year',
#  'mileage',
#  'mileage_unit',
#  'model',
#  'model_variant',
#  'price_on_request',
#  'type',
#  'zip',
#  'manufacture_month',
#  'fuel_consumption_unit']

# %%
data_rn = data.rename({
    'BodyTypeText': "carType",               # assumed normalized
    'ConditionTypeText': "condition",        # assumed normalized
    'City': 'city',                        
    'ModelText': 'model',                    # assumed normalized
    'ModelTypeText': 'model_variant',        # assumed normalized
    'Km': 'mileage',                         # assumed normalized
    'Country': 'country'                  
}, axis=1)

# %% [markdown]
# ### 3.3. Drop other columns

# %%
# # columns to drop
# to_drop = [
#     'BodyColorText',            # normalised into color
#     'DriveTypeText',            # no match in target attributes
#     'MakeText',                 # normalised into make
#     'TransmissionTypeText',     # no match in target attributes
#     'FirstRegMonth',            # no match in target attributes
#     'FirstRegYear',             # no match in target attributes
#     'Ccm',                      # no match in target attributes
#     'Co2EmissionText',          # no match in target attributes
#     'ConsumptionRatingText',    # no match in target attributes
#     'ConsumptionTotalText',     # no match in target attributes
#     'Doors',                    # no match in target attributes
#     'FuelTypeText',             # no match in target attributes
#     'Hp',                       # no match in target attributes
#     'InteriorColorText',        # no match in target attributes
#     'Properties',               # no match in target attributes
#     'Seats',                    # no match in target attributes
#     'TypeName',                 # redundant
#     'BodyColorText_new',        # used for color normalisation
#     'BodyColorText_trans'       # used for color normalisation
# ]

# drop automatically cols that are unmatched
cols_to_drop = []
for col in data_rn.columns:
    if col not in data_tar.columns:
        cols_to_drop.append(col)
        

data_rn = data_rn.drop(columns=cols_to_drop)

data_rn

# %% [markdown]
# ### 3.4. Append normalised supplier dataset to target dataset
#
# Produce an integrated supplier data set. Replace nan with null to make it consistent

# %%
data_rn = data_rn.reset_index(drop=True) # reset the ID index

# %%
data_comb = data_tar.append(data_rn, ignore_index=True)
data_comb = data_comb.fillna('null')

# %% [markdown]
# ### 3.5. Save whole project as an xls file according to task description

# %%
# load preprocessed file
file_prepro = './output/preprocessing/preprocessing.csv'
df_prepro = pd.read_csv(file_prepro, index_col=0)

# load normalised file
file_norm = './output/normalisation/normalisation.csv'
df_norm = pd.read_csv(file_norm, index_col=0)

# combined datafile
df_comb = data_comb
df_comb
# Out:
#                      carType  color           condition currency drive  \
# 0     Convertible / Roadster  White                Used      USD   LHD
# 1     Convertible / Roadster  Other  Original Condition      USD   LHD
# 2     Convertible / Roadster  White                Used      USD   LHD
# 3     Convertible / Roadster   Blue                Used      USD   LHD
# 4     Convertible / Roadster  Black  Original Condition      USD   LHD
# ...                      ...    ...                 ...      ...   ...
# 8400               Limousine  White            Occasion     null  null
# 8401               Limousine  White            Occasion     null  null
# 8402               Limousine  White            Occasion     null  null
# 8403                   Coupé  White            Occasion     null  null
# 8404                   Kombi  White            Occasion     null  null
#
#                city country           make manufacture_year mileage  \
# 0            Zuzwil      CH         Toyota             1983       0
# 1            London      GB        Ferrari             2001       0
# 2     Scotts Valley      US        Porsche             1989       0
# 3            London      GB    Rolls-Royce             1961       0
# 4         Hong Kong      HK        Gumpert             2010       0
# ...             ...     ...            ...              ...     ...
# 8400         Zuzwil      CH  Mercedes-Benz             null  102000
# 8401         Zuzwil      CH            BMW             null   39700
# 8402         Zuzwil      CH  Mercedes-Benz             null   99000
# 8403     Porrentruy      CH    Lamborghini             null    5900
# 8404         Zuzwil      CH           Audi             null   55000
#
#      mileage_unit            model      model_variant price_on_request  type  \
# 0       kilometer           Celica       2800 i Supra            False   car
# 1            mile              550               null             True   car
# 2            mile          911 "G"               null             True   car
# 3       kilometer  Silver Cloud II               null            False   car
# 4       kilometer           Apollo     Apollo S 800hp            False   car
# ...           ...              ...                ...              ...   ...
# 8400         null         S 65 AMG         S 65 AMG L             null  null
# 8401         null               M5                 M5             null  null
# 8402         null            A 150      A 150 Classic             null  null
# 8403         null             null     Reventon Coupé             null  null
# 8404         null              RS6  RS6 Avant quattro             null  null
#
#        zip manufacture_month fuel_consumption_unit
# 0     null                 3      l_km_consumption
# 1     null              null                  null
# 2     null              null                  null
# 3     null              null                  null
# 4     null              null                  null
# ...    ...               ...                   ...
# 8400  null              null                  null
# 8401  null              null                  null
# 8402  null              null                  null
# 8403  null              null                  null
# 8404  null              null                  null
#
# [8405 rows x 18 columns]

# %%
def apply_autofilter(writer, n_rows, n_cols, sheet_name):
    """
    Applies an autofilter to the columns based on the sheetname.
    """
    # Get the xlsxwriter objects from the dataframe writer object.
    workbook  = writer.book
    worksheet = writer.sheets[sheet_name]
    # Apply the autofilter based on the dimensions of the dataframe.
    worksheet.autofilter(0, 0, n_rows, n_cols)
    
    
path_output_xls = "test.xlsx"
with pd.ExcelWriter(path_output_xls, engine = 'xlsxwriter') as writer:  
    sheet_name = 'Pre-processing'
    df_prepro.to_excel(writer, sheet_name=sheet_name)
    n_rows, n_cols = df_prepro.shape[0], df_prepro.shape[1]
    apply_autofilter(writer, n_rows, n_cols, sheet_name)
    
    sheet_name = 'Normalisation'
    df_norm.to_excel(writer, sheet_name=sheet_name)
    n_rows, n_cols = df_norm.shape[0], df_norm.shape[1]
    apply_autofilter(writer, n_rows, n_cols, sheet_name)
    
    sheet_name = 'Integration'
    df_comb.to_excel(writer, sheet_name=sheet_name, index=None)    
    n_rows, n_cols = df_comb.shape[0], df_comb.shape[1]
    apply_autofilter(writer, n_rows, n_cols, sheet_name)

# %%
def test_final_xls(data_tar, df_norm, df_comb):
    """
    Test for the final xls file.
    """
    assert data_tar.shape[0] + df_norm.shape[0] == df_comb.shape[0], "Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset."
    assert data_tar.shape[1] == df_comb.shape[1], "Error in test_final_xls! Number of columns in combined dataset is not equal to number of columns in combined dataset."

test_final_xls(data_tar, df_norm, df_comb)

# %%
test_final_xls(data_tar, df_norm, df_comb.drop(columns=['country'], axis=1))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-69-b2309e53fa3c> in <module>
# ----> 1 test_final_xls(data_tar, df_norm, df_comb.drop(columns=['country'], axis=1))
#
# <ipython-input-68-1ecd1a87e5bb> in test_final_xls(data_tar, df_norm, df_comb)
#       4     """
#       5     assert data_tar.shape[0] + df_norm.shape[0] == df_comb.shape[0], "Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset."
# ----> 6     assert data_tar.shape[1] == df_comb.shape[1], "Error in test_final_xls! Number of columns in combined dataset is not equal to number of columns in combined dataset."
#       7
#       8 test_final_xls(data_tar, df_norm, df_comb)
#
# AssertionError: Error in test_final_xls! Number of columns in combined dataset is not equal to number of columns in combined dataset.

# %%
test_final_xls(data_tar, df_norm.drop(df_norm.tail(4).index, axis=0), df_comb)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-63-0dd6852d3a69> in <module>
# ----> 1 test_final_xls(data_tar, df_norm.drop(df_norm.tail(4).index, axis=0), df_comb)
#
# <ipython-input-59-7351fc82e172> in test_final_xls(data_tar, df_norm, df_comb)
#       3     Test for the final xls file.
#       4     """
# ----> 5     assert data_tar.shape[0] + df_norm.shape[0] == df_comb.shape[0], "Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset."
#       6     assert data_tar.shape[1] == df_comb.shape[1], "Error in test_final_xls! Number of columns in combined dataset is not equal to number of columns in combined dataset."
#       7
#
# AssertionError: Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset.

# %%
test_final_xls(data_tar, df_norm, df_comb.drop(df_norm.tail(234).index, axis=0))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-65-f41d98eaabd4> in <module>
# ----> 1 test_final_xls(data_tar, df_norm, df_comb.drop(df_norm.tail(234).index, axis=0))
#
# <ipython-input-59-7351fc82e172> in test_final_xls(data_tar, df_norm, df_comb)
#       3     Test for the final xls file.
#       4     """
# ----> 5     assert data_tar.shape[0] + df_norm.shape[0] == df_comb.shape[0], "Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset."
#       6     assert data_tar.shape[1] == df_comb.shape[1], "Error in test_final_xls! Number of columns in combined dataset is not equal to number of columns in combined dataset."
#       7
#
# AssertionError: Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset.

# %%
test_final_xls(data_tar.drop(df_norm.tail(25).index, axis=0), df_norm, df_comb)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-66-0f6535731d0f> in <module>
# ----> 1 test_final_xls(data_tar.drop(df_norm.tail(25).index, axis=0), df_norm, df_comb)
#
# <ipython-input-59-7351fc82e172> in test_final_xls(data_tar, df_norm, df_comb)
#       3     Test for the final xls file.
#       4     """
# ----> 5     assert data_tar.shape[0] + df_norm.shape[0] == df_comb.shape[0], "Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset."
#       6     assert data_tar.shape[1] == df_comb.shape[1], "Error in test_final_xls! Number of columns in combined dataset is not equal to number of columns in combined dataset."
#       7
#
# AssertionError: Error in test_final_xls! Number of rows in combined dataset is not equal to number of rows in target dataset plus normalised dataset.

# %% [markdown]
# ## 4. Check the pipeline

# %% [markdown]
# ### 4.1 Preprocessing

# %%
s1 = './output/preprocessing/preprocessing_0.csv'
s2 = './output/preprocessing/preprocessing.csv'
df_0 = pd.read_csv(s1)
df_1 = pd.read_csv(s2)
df_0.equals(df_1)
# Out:
# True

# %% [markdown]
# ### 4.4. Normalisation

# %%
s1 = './output/normalisation/normalisation_0.csv'
s2 = './output/normalisation/normalisation.csv'
df_0 = pd.read_csv(s1)
df_1 = pd.read_csv(s2)
df_0.equals(df_1)
# Out:
# True

# %% [markdown]
# ### 4.1 Preprocessing

# %% [markdown]
# ### 4.3. Integration

# %%
s1 = './output/integration/integration_0.csv'
s2 = './output/integration/integration.csv'
df_0 = pd.read_csv(s1)
df_1 = pd.read_csv(s2)
df_0.equals(df_1)
# Out:
# True
